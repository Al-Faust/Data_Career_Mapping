# %%
import numpy as np
import pandas as pd
import sys
import re

# %%
das_df = pd.read_csv('das.csv')

# %% [markdown]
# Setting up dataframe exactly like data_cleaning

# %%
das_df.head()
# Out:
#                         Job Title              Salary Estimate  \
# 0                    Data Analyst  $41K-$78K\n(Glassdoor est.)
# 1                    Data Analyst  $35K-$70K\n(Glassdoor est.)
# 2  Finance Data Analytics Analyst  $37K-$67K\n(Glassdoor est.)
# 3            Data Systems Analyst  $34K-$60K\n(Glassdoor est.)
# 4                    Data Analyst  $36K-$66K\n(Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Sony Electronics, Inc. look for the risk-taker...     4.1
# 1  Data Specialist\n\nJob Summary\n\nWe are on th...     4.9
# 2  Your Opportunity:\n\nSmithfield Foods is a $15...     3.2
# 3  Ready to make an impact? If so, read on!\n\nWo...     3.4
# 4  WHAT YOU WILL DO IN THIS POSITION:\n\n·Perform...     4.4
#
#             Company Name          Location                   Size  Founded  \
# 0  Sony Electronics\n4.1       Paramus, NJ       10000+ Employees   1946.0
# ...

# %%
das_df.columns = das_df.columns.str.replace(' ', '_')
das_df.columns
# Out:
# Index(['Job_Title', 'Salary_Estimate', 'Job_Description', 'Rating',
#        'Company_Name', 'Location', 'Size', 'Founded', 'Type_of_ownership',
#        'Industry', 'Sector', 'Revenue'],
#       dtype='object')

# %%
# Drop the rows that do not have salary estimate
das_df = das_df[das_df['Salary_Estimate'] != '-1']

# %%
#das_df.head()
das_df['Salary_Estimate'] = das_df['Salary_Estimate'].str.replace('Employer Provided Salary:\n', '')
das_df
# Out:
#                           Job_Title              Salary_Estimate  \
# 0                      Data Analyst  $41K-$78K\n(Glassdoor est.)
# 1                      Data Analyst  $35K-$70K\n(Glassdoor est.)
# 2    Finance Data Analytics Analyst  $37K-$67K\n(Glassdoor est.)
# 3              Data Systems Analyst  $34K-$60K\n(Glassdoor est.)
# 4                      Data Analyst  $36K-$66K\n(Glassdoor est.)
# ..                              ...                          ...
# 788                             NaN                          NaN
# 789                             NaN                          NaN
# 790                             NaN                          NaN
# 791                             NaN                          NaN
# 792                             NaN                          NaN
#
#                                        Job_Description  Rating  \
# 0    Sony Electronics, Inc. look for the risk-taker...     4.1
# ...

# %%
das_df = das_df.dropna(how = 'all')
#das_df

# %%
das_df
# Out:
#                                              Job_Title  \
# 0                                         Data Analyst
# 1                                         Data Analyst
# 2                       Finance Data Analytics Analyst
# 3                                 Data Systems Analyst
# 4                                         Data Analyst
# ..                                                 ...
# 773                   JPSC-8710 - Oracle Data Analysts
# 775                                       Data Analyst
# 776                                       Data Analyst
# 783  Data Analyst Supporting the US Attorney's Offi...
# 785  Data Analyst Supporting the US Attorney's Offi...
#
#                  Salary_Estimate  \
# 0    $41K-$78K\n(Glassdoor est.)
# 1    $35K-$70K\n(Glassdoor est.)
# 2    $37K-$67K\n(Glassdoor est.)
# 3    $34K-$60K\n(Glassdoor est.)
# 4    $36K-$66K\n(Glassdoor est.)
# ..                           ...
# 773  $43K-$80K\n(Glassdoor est.)
# ...

# %%
# remove additional text
#das_df['Salary_Estimate'] = das_df['Salary_Estimate'].apply(lambda x: x.split('\n')[0])

# %%
#das_df[das_df['Salary_Estimate'].str.contains("Per Hour")]

# %%
#das_df['hourly'] = das_df['Salary_Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
